# %%
import pandas as pd
import numpy as np

# %%
file_path = r'C:\Users\SURFACE\Downloads\archive food\Top 100 Healthiest Food in the World.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#           Food   Nutrition Value (per 100g)        Quantity  \
# 0         Kale     High in Vitamins A, C, K  1 cup, chopped
# 1  Blueberries         High in Antioxidants           1 cup
# 2       Salmon  Rich in Omega-3 Fatty Acids            3 oz
# 3       Garlic             Contains Allicin         1 clove
# 4      Spinach      High in Iron and Folate      1 cup, raw
#
#        Originated From  Calories  Protein (g)  Fiber (g)  Vitamin C (mg)  \
# 0       Ancient Greece        49          4.3        3.6            93.4
# 1        North America        84          1.1        3.6            14.4
# 2  North Pacific Ocean       208         22.1        0.0             0.0
# 3         Central Asia         4          0.2        0.1             0.9
# 4       Ancient Persia        23          2.9        2.2            28.1
#
#    Antioxidant Score
# 0               1770
# 1               9621
# 2                689
# 3               5708
# 4               1515

# %%
#To serach for missing values
df.isnull().sum()
# Out:
# Food                          0
# Nutrition Value (per 100g)    0
# Quantity                      0
# Originated From               0
# Calories                      0
# Protein (g)                   0
# Fiber (g)                     0
# Vitamin C (mg)                0
# Antioxidant Score             0
# dtype: int64

# %%
# To Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Food                           object
# Nutrition Value (per 100g)     object
# Quantity                       object
# Originated From                object
# Calories                        int64
# Protein (g)                   float64
# Fiber (g)                     float64
# Vitamin C (mg)                float64
# Antioxidant Score               int64
# dtype: object

# %%
# Plot histograms for numeric columns
numeric_columns = ['Calories', 'Protein (g)', 'Fiber (g)', 'Vitamin C (mg)']
df[numeric_columns].hist(bins=15, figsize=(15, 10), layout=(2, 2), edgecolor='black')
plt.suptitle('Distribution of Nutritional Values')
plt.show()

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=[np.number])

# Compute the correlation matrix
corr = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
"""
In this analysis, I explored the nutritional profiles of the top 100 healthiest foods, examining their caloric 
content, protein, fiber, vitamin C, and antioxidant scores. The correlation analysis provided insights into how 
these nutritional values relate to each other.
"""
# Out:
# '\nIn this analysis, I explored the nutritional profiles of the top 100 healthiest foods, examining their caloric \ncontent, protein, fiber, vitamin C, and antioxidant scores. The correlation analysis provided insights into how \nthese nutritional values relate to each other.\n'
