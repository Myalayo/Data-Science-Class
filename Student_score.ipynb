# %%
import random

# Generate raw scores for 50 students
# Each student must answer either question 1 or 2 and any other 3 questions (4 in total out of 8)

# Define the number of students and number of questions
num_students = 50
num_questions = 8
questions_to_answer = 4

# Generate raw scores for each student, with each question carrying a maximum of 20 marks
students_scores_adjusted = []

for student in range(num_students):
    # Select either question 1 or 2 first
    first_question = random.choice([1, 2])
    
    # Choose 3 additional questions from the remaining 6 (excluding the first chosen question)
    other_questions = random.sample([q for q in range(3, num_questions + 1) if q != first_question], 3)
    
    # Collect all the questions answered
    answered_questions = [first_question] + other_questions
    
    # Generate random scores (between 0 and 20) for each answered question
    scores = {f"Q{q}": random.randint(0, 20) for q in answered_questions}
    
    students_scores_adjusted.append({"StudentID": f"Student{student + 1}", "Scores": scores})

# Display the first 5 students' scores with the adjusted 20-mark scale
students_scores_adjusted[:51]
# Out:
# [{'StudentID': 'Student1', 'Scores': {'Q1': 13, 'Q3': 16, 'Q8': 9, 'Q6': 7}},
#  {'StudentID': 'Student2', 'Scores': {'Q2': 12, 'Q3': 19, 'Q4': 13, 'Q6': 7}},
#  {'StudentID': 'Student3', 'Scores': {'Q1': 9, 'Q8': 2, 'Q3': 4, 'Q6': 8}},
#  {'StudentID': 'Student4', 'Scores': {'Q1': 1, 'Q8': 16, 'Q5': 12, 'Q6': 16}},
#  {'StudentID': 'Student5', 'Scores': {'Q2': 7, 'Q3': 5, 'Q4': 14, 'Q8': 19}},
#  {'StudentID': 'Student6', 'Scores': {'Q1': 8, 'Q7': 20, 'Q4': 20, 'Q3': 11}},
#  {'StudentID': 'Student7', 'Scores': {'Q2': 11, 'Q3': 15, 'Q8': 5, 'Q6': 3}},
#  {'StudentID': 'Student8', 'Scores': {'Q2': 14, 'Q6': 9, 'Q8': 8, 'Q4': 13}},
#  {'StudentID': 'Student9', 'Scores': {'Q1': 17, 'Q7': 2, 'Q5': 0, 'Q4': 17}},
#  {'StudentID': 'Student10', 'Scores': {'Q1': 13, 'Q4': 4, 'Q3': 6, 'Q5': 17}},
#  {'StudentID': 'Student11', 'Scores': {'Q1': 11, 'Q8': 0, 'Q3': 11, 'Q7': 10}},
#  {'StudentID': 'Student12', 'Scores': {'Q2': 20, 'Q5': 20, 'Q3': 6, 'Q6': 8}},
#  {'StudentID': 'Student13', 'Scores': {'Q1': 6, 'Q7': 6, 'Q8': 17, 'Q5': 12}},
#  {'StudentID': 'Student14', 'Scores': {'Q2': 3, 'Q8': 18, 'Q6': 14, 'Q4': 0}},
#  {'StudentID': 'Student15', 'Scores': {'Q2': 7, 'Q7': 20, 'Q6': 13, 'Q4': 14}},
#  {'StudentID': 'Student16', 'Scores': {'Q2': 18, 'Q6': 16, 'Q4': 17, 'Q3': 8}},
#  {'StudentID': 'Student17', 'Scores': {'Q1': 17, 'Q5': 12, 'Q8': 0, 'Q4': 13}},
#  {'StudentID': 'Student18', 'Scores': {'Q1': 3, 'Q6': 20, 'Q5': 2, 'Q8': 11}},
#  {'StudentID': 'Student19', 'Scores': {'Q2': 15, 'Q5': 6, 'Q6': 20, 'Q4': 3}},
#  {'StudentID': 'Student20',
#   'Scores': {'Q1': 16, 'Q3': 13, 'Q5': 14, 'Q7': 14}},
#  {'StudentID': 'Student21',
#   'Scores': {'Q2': 11, 'Q4': 20, 'Q3': 11, 'Q6': 11}},
#  {'StudentID': 'Student22', 'Scores': {'Q1': 0, 'Q3': 11, 'Q5': 15, 'Q8': 9}},
#  {'StudentID': 'Student23', 'Scores': {'Q2': 2, 'Q4': 11, 'Q5': 15, 'Q6': 18}},
#  {'StudentID': 'Student24', 'Scores': {'Q1': 8, 'Q6': 10, 'Q5': 7, 'Q3': 16}},
#  {'StudentID': 'Student25', 'Scores': {'Q2': 7, 'Q4': 18, 'Q8': 11, 'Q5': 4}},
#  {'StudentID': 'Student26', 'Scores': {'Q1': 6, 'Q4': 17, 'Q8': 20, 'Q6': 7}},
#  {'StudentID': 'Student27',
#   'Scores': {'Q1': 13, 'Q7': 18, 'Q4': 10, 'Q3': 12}},
#  {'StudentID': 'Student28',
#   'Scores': {'Q2': 13, 'Q5': 20, 'Q7': 11, 'Q6': 14}},
#  {'StudentID': 'Student29',
#   'Scores': {'Q1': 15, 'Q7': 10, 'Q6': 19, 'Q4': 13}},
#  {'StudentID': 'Student30', 'Scores': {'Q1': 7, 'Q3': 18, 'Q4': 3, 'Q5': 15}},
#  {'StudentID': 'Student31', 'Scores': {'Q1': 1, 'Q5': 17, 'Q4': 3, 'Q6': 10}},
#  {'StudentID': 'Student32', 'Scores': {'Q1': 13, 'Q4': 1, 'Q5': 19, 'Q3': 20}},
#  {'StudentID': 'Student33', 'Scores': {'Q1': 6, 'Q7': 15, 'Q3': 16, 'Q5': 15}},
#  {'StudentID': 'Student34',
#   'Scores': {'Q2': 14, 'Q8': 10, 'Q4': 16, 'Q6': 13}},
#  {'StudentID': 'Student35', 'Scores': {'Q1': 7, 'Q6': 7, 'Q3': 6, 'Q5': 8}},
#  {'StudentID': 'Student36', 'Scores': {'Q2': 7, 'Q5': 6, 'Q3': 6, 'Q8': 7}},
#  {'StudentID': 'Student37', 'Scores': {'Q1': 19, 'Q5': 0, 'Q7': 5, 'Q6': 4}},
#  {'StudentID': 'Student38', 'Scores': {'Q1': 19, 'Q6': 1, 'Q5': 9, 'Q3': 9}},
#  {'StudentID': 'Student39', 'Scores': {'Q2': 6, 'Q6': 9, 'Q4': 14, 'Q3': 3}},
#  {'StudentID': 'Student40', 'Scores': {'Q1': 3, 'Q4': 20, 'Q7': 16, 'Q5': 17}},
#  {'StudentID': 'Student41',
#   'Scores': {'Q1': 18, 'Q8': 14, 'Q7': 18, 'Q3': 11}},
#  {'StudentID': 'Student42', 'Scores': {'Q1': 9, 'Q7': 9, 'Q6': 6, 'Q3': 12}},
#  {'StudentID': 'Student43', 'Scores': {'Q2': 8, 'Q7': 14, 'Q4': 15, 'Q5': 20}},
#  {'StudentID': 'Student44', 'Scores': {'Q1': 10, 'Q7': 9, 'Q8': 8, 'Q5': 0}},
#  {'StudentID': 'Student45', 'Scores': {'Q2': 11, 'Q4': 16, 'Q8': 18, 'Q3': 2}},
#  {'StudentID': 'Student46', 'Scores': {'Q1': 4, 'Q6': 19, 'Q4': 17, 'Q5': 0}},
#  {'StudentID': 'Student47', 'Scores': {'Q2': 5, 'Q4': 14, 'Q5': 10, 'Q7': 4}},
#  {'StudentID': 'Student48',
#   'Scores': {'Q2': 14, 'Q3': 14, 'Q7': 18, 'Q8': 10}},
#  {'StudentID': 'Student49', 'Scores': {'Q1': 2, 'Q5': 5, 'Q4': 8, 'Q8': 4}},
#  {'StudentID': 'Student50',
#   'Scores': {'Q1': 16, 'Q8': 15, 'Q6': 18, 'Q4': 15}}]

# %%
students_scores_adjusted
# Out:
# [{'StudentID': 'Student1', 'Scores': {'Q1': 13, 'Q3': 16, 'Q8': 9, 'Q6': 7}},
#  {'StudentID': 'Student2', 'Scores': {'Q2': 12, 'Q3': 19, 'Q4': 13, 'Q6': 7}},
#  {'StudentID': 'Student3', 'Scores': {'Q1': 9, 'Q8': 2, 'Q3': 4, 'Q6': 8}},
#  {'StudentID': 'Student4', 'Scores': {'Q1': 1, 'Q8': 16, 'Q5': 12, 'Q6': 16}},
#  {'StudentID': 'Student5', 'Scores': {'Q2': 7, 'Q3': 5, 'Q4': 14, 'Q8': 19}},
#  {'StudentID': 'Student6', 'Scores': {'Q1': 8, 'Q7': 20, 'Q4': 20, 'Q3': 11}},
#  {'StudentID': 'Student7', 'Scores': {'Q2': 11, 'Q3': 15, 'Q8': 5, 'Q6': 3}},
#  {'StudentID': 'Student8', 'Scores': {'Q2': 14, 'Q6': 9, 'Q8': 8, 'Q4': 13}},
#  {'StudentID': 'Student9', 'Scores': {'Q1': 17, 'Q7': 2, 'Q5': 0, 'Q4': 17}},
#  {'StudentID': 'Student10', 'Scores': {'Q1': 13, 'Q4': 4, 'Q3': 6, 'Q5': 17}},
#  {'StudentID': 'Student11', 'Scores': {'Q1': 11, 'Q8': 0, 'Q3': 11, 'Q7': 10}},
#  {'StudentID': 'Student12', 'Scores': {'Q2': 20, 'Q5': 20, 'Q3': 6, 'Q6': 8}},
#  {'StudentID': 'Student13', 'Scores': {'Q1': 6, 'Q7': 6, 'Q8': 17, 'Q5': 12}},
#  {'StudentID': 'Student14', 'Scores': {'Q2': 3, 'Q8': 18, 'Q6': 14, 'Q4': 0}},
#  {'StudentID': 'Student15', 'Scores': {'Q2': 7, 'Q7': 20, 'Q6': 13, 'Q4': 14}},
#  {'StudentID': 'Student16', 'Scores': {'Q2': 18, 'Q6': 16, 'Q4': 17, 'Q3': 8}},
#  {'StudentID': 'Student17', 'Scores': {'Q1': 17, 'Q5': 12, 'Q8': 0, 'Q4': 13}},
#  {'StudentID': 'Student18', 'Scores': {'Q1': 3, 'Q6': 20, 'Q5': 2, 'Q8': 11}},
#  {'StudentID': 'Student19', 'Scores': {'Q2': 15, 'Q5': 6, 'Q6': 20, 'Q4': 3}},
#  {'StudentID': 'Student20',
#   'Scores': {'Q1': 16, 'Q3': 13, 'Q5': 14, 'Q7': 14}},
#  {'StudentID': 'Student21',
#   'Scores': {'Q2': 11, 'Q4': 20, 'Q3': 11, 'Q6': 11}},
#  {'StudentID': 'Student22', 'Scores': {'Q1': 0, 'Q3': 11, 'Q5': 15, 'Q8': 9}},
#  {'StudentID': 'Student23', 'Scores': {'Q2': 2, 'Q4': 11, 'Q5': 15, 'Q6': 18}},
#  {'StudentID': 'Student24', 'Scores': {'Q1': 8, 'Q6': 10, 'Q5': 7, 'Q3': 16}},
#  {'StudentID': 'Student25', 'Scores': {'Q2': 7, 'Q4': 18, 'Q8': 11, 'Q5': 4}},
#  {'StudentID': 'Student26', 'Scores': {'Q1': 6, 'Q4': 17, 'Q8': 20, 'Q6': 7}},
#  {'StudentID': 'Student27',
#   'Scores': {'Q1': 13, 'Q7': 18, 'Q4': 10, 'Q3': 12}},
#  {'StudentID': 'Student28',
#   'Scores': {'Q2': 13, 'Q5': 20, 'Q7': 11, 'Q6': 14}},
#  {'StudentID': 'Student29',
#   'Scores': {'Q1': 15, 'Q7': 10, 'Q6': 19, 'Q4': 13}},
#  {'StudentID': 'Student30', 'Scores': {'Q1': 7, 'Q3': 18, 'Q4': 3, 'Q5': 15}},
#  {'StudentID': 'Student31', 'Scores': {'Q1': 1, 'Q5': 17, 'Q4': 3, 'Q6': 10}},
#  {'StudentID': 'Student32', 'Scores': {'Q1': 13, 'Q4': 1, 'Q5': 19, 'Q3': 20}},
#  {'StudentID': 'Student33', 'Scores': {'Q1': 6, 'Q7': 15, 'Q3': 16, 'Q5': 15}},
#  {'StudentID': 'Student34',
#   'Scores': {'Q2': 14, 'Q8': 10, 'Q4': 16, 'Q6': 13}},
#  {'StudentID': 'Student35', 'Scores': {'Q1': 7, 'Q6': 7, 'Q3': 6, 'Q5': 8}},
#  {'StudentID': 'Student36', 'Scores': {'Q2': 7, 'Q5': 6, 'Q3': 6, 'Q8': 7}},
#  {'StudentID': 'Student37', 'Scores': {'Q1': 19, 'Q5': 0, 'Q7': 5, 'Q6': 4}},
#  {'StudentID': 'Student38', 'Scores': {'Q1': 19, 'Q6': 1, 'Q5': 9, 'Q3': 9}},
#  {'StudentID': 'Student39', 'Scores': {'Q2': 6, 'Q6': 9, 'Q4': 14, 'Q3': 3}},
#  {'StudentID': 'Student40', 'Scores': {'Q1': 3, 'Q4': 20, 'Q7': 16, 'Q5': 17}},
#  {'StudentID': 'Student41',
#   'Scores': {'Q1': 18, 'Q8': 14, 'Q7': 18, 'Q3': 11}},
#  {'StudentID': 'Student42', 'Scores': {'Q1': 9, 'Q7': 9, 'Q6': 6, 'Q3': 12}},
#  {'StudentID': 'Student43', 'Scores': {'Q2': 8, 'Q7': 14, 'Q4': 15, 'Q5': 20}},
#  {'StudentID': 'Student44', 'Scores': {'Q1': 10, 'Q7': 9, 'Q8': 8, 'Q5': 0}},
#  {'StudentID': 'Student45', 'Scores': {'Q2': 11, 'Q4': 16, 'Q8': 18, 'Q3': 2}},
#  {'StudentID': 'Student46', 'Scores': {'Q1': 4, 'Q6': 19, 'Q4': 17, 'Q5': 0}},
#  {'StudentID': 'Student47', 'Scores': {'Q2': 5, 'Q4': 14, 'Q5': 10, 'Q7': 4}},
#  {'StudentID': 'Student48',
#   'Scores': {'Q2': 14, 'Q3': 14, 'Q7': 18, 'Q8': 10}},
#  {'StudentID': 'Student49', 'Scores': {'Q1': 2, 'Q5': 5, 'Q4': 8, 'Q8': 4}},
#  {'StudentID': 'Student50',
#   'Scores': {'Q1': 16, 'Q8': 15, 'Q6': 18, 'Q4': 15}}]
